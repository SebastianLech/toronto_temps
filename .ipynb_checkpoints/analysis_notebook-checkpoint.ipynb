# %% [markdown]
# # Time Series Analysis of Toronto Temperatures
# In this notebook we attempt to forecast the temperature in Toronto by fitting a time series model based on past temperature data. Data is gathered from https://climate.weather.gc.ca/.  We begin by retrieving the data using a bash script, followed by a prelimenary examination of the data, to ensure its quality and develop some intuition.  Next, we assess the stationarity of the series, extract its deterministic trend and model the residual noise.  Lastly, we extend our model by ___ days and analyze the forecasts.
#
# ## Parts
# 1. Gathering Data
# 2. Exploratory Analysis
# 3. Assessing Stationarity
# 4. Model Fitting
# 5. Forecasts
#
# ## Purpose
# This analysis is not expected to generate overly accurate temperature forecasts.  Weather in general is a very complex phenomena and requires intimate meteoroligical knowledge to model correctly.  Instead, this notebook serves as an exercise in model fitting/forecasting while breifly touching on some of the nuances of temperature forecasting.  Details focus on the statistical analysis itself more so than the weather.

# %% [markdown]
# # 1. Gathering Data
# Before we can perform any sort of analysis, we need data.  Luckily, the Government of Canada provides an abundance of temperature records for most major cities across Canada.  Data can be searched for at https://climate.weather.gc.ca/historical_data/search_historic_data_e.html which returns various weather metrics for stations located throughout a city.  In the case of Toronto, although there are many records, station data is rather unorganized and can range anywhere from hourly temperatures between 1953-1969 to monthly temperatures between 1840-2006.  Since a group of stations within particular region will not each have data for a specified timeframe we pick a single station and base our analysis using only its data.  Documenation on getting data is provided by the Government of Canada here https://drive.google.com/drive/folders/1WJCDEU34c60IfOnG4rv5EPZ4IhhW9vZH which contians a csv with geographical station information.  Since it contains daily data since 2002 and is close to downtown, we opt for the Toronto City station (ID: 31688) for our analysis

# %% [markdown]
# ![title](Rplot.png)

# %% [markdown]
# The documentation located in the google drive above also provides a simple bash script to retrieve the weather data.  (slightly modified) It is
# ```
# #!/bin/bash
# for year in `seq 2002 2021`
# do
#     wget -O "${year}_daily_temperature_31688.csv" "https://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=31688&Year=${year}&Month=1&Day=14&timeframe=2&submit= Download+Data"
# done
#
# ```
# which will create 20 seperate csv files, each of whom contain daily weather data for their respectve year.  To avoid having to merge each file using R we can append their contents to a single file containing all year's data using shell
# ```
# head -n 1 2002_daily_temperature_31688.csv > 2002_2021_daily_temps.csv && tail -n+2 -q *.csv >> 2002_2021_daily_temps.csv
# ```
# Now that we have our data, we can start exploring.
#
# In order to keep the analysis more managable, we will only use data between 2017 and 2021.

# %% [markdown]
# # 2. Exploring Data

# %%
library(ggplot2)
library(lubridate)
library(dplyr)
library(astsa)
library(TSA)
library(glue)
library(gdata)
library(tseries)
library(forecast)
library(gridExtra)
options(repr.plot.width=15, repr.plot.height=8)
mapviewOptions(fgb = FALSE)

# %%
weather_data <- read.csv('data/2002_2021_daily_temps.csv', header=TRUE)   # read data
names(weather_data)[c(1, 2, 10, 12, 14)] = c('longitude', 
                                             'latitude', 
                                             'max.temp', 
                                             'min.temp', 
                                             'mean.temp')
temp_data <- weather_data[c(5, 6, 7, 8, 10, 12, 14)] # only keep temperatures                   
temp_data$Date.Time <- as.Date(temp_data$Date.Time, format="%Y-%m-%d")  
temp_data$Month <- month.abb[temp_data$Month]
start <- as.Date('2017-01-01', format('%Y-%m-%d'))
end <- as.Date('2021-05-07', format('%Y-%m-%d'))
working_temps <- temp_data[temp_data[, 1] >= start & temp_data[, 1] <= end, ]

# %% [markdown]
# As with any data science project, there will be some inconsistencies in the data.  The first thing we want to check for is missing data.  Below we notice that there are 34 days missing mean temperatures, located throughout the data set.  Rather than manually looking up 34 seperate days from other sources of weather data we will linearly interpolate to fill in the blanks.

# %%
working_temps[!complete.cases(working_temps),] # identify missing (NA) mean temps
# Out:
#      Date.Time  Year Month Day max.temp min.temp mean.temp
# 5544 2017-03-06 2017 Mar    6   4.9       NA     NA
# 5580 2017-04-11 2017 Apr   11    NA     11.3     NA
# 5617 2017-05-18 2017 May   18    NA     18.4     NA
# 5621 2017-05-22 2017 May   22    NA       NA     NA
# 5622 2017-05-23 2017 May   23  21.8       NA     NA
# 5628 2017-05-29 2017 May   29    NA     14.7     NA
# 5637 2017-06-07 2017 Jun    7    NA       NA     NA
# 5782 2017-10-30 2017 Oct   30    NA      5.9     NA
# 5790 2017-11-07 2017 Nov    7    NA      4.0     NA
# 5810 2017-11-27 2017 Nov   27    NA      1.3     NA
# 5903 2018-02-28 2018 Feb   28    NA      5.1     NA
# 5904 2018-03-01 2018 Mar    1    NA       NA     NA
# 5905 2018-03-02 2018 Mar    2    NA     -0.5     NA
# 5906 2018-03-03 2018 Mar    3    NA       NA     NA
# 5907 2018-03-04 2018 Mar    4    NA     -3.1     NA
# 5908 2018-03-05 2018 Mar    5    NA       NA     NA
# 5909 2018-03-06 2018 Mar    6    NA     -1.4     NA
# 5943 2018-04-09 2018 Apr    9    NA     -3.6     NA
# 6002 2018-06-07 2018 Jun    7    NA       NA     NA
# 6037 2018-07-12 2018 Jul   12    NA       NA     NA
# 6038 2018-07-13 2018 Jul   13  30.6       NA     NA
# 6039 2018-07-14 2018 Jul   14    NA       NA     NA
# 6040 2018-07-15 2018 Jul   15  30.9       NA     NA
# 6041 2018-07-16 2018 Jul   16    NA       NA     NA
# 6153 2018-11-05 2018 Nov    5    NA       NA     NA
# 6194 2018-12-16 2018 Dec   16    NA       NA     NA
# 6195 2018-12-17 2018 Dec   17    NA       NA     NA
# 6314 2019-04-15 2019 Apr   15    NA       NA     NA
# 6443 2019-08-22 2019 Aug   22    NA       NA     NA
# 6567 2019-12-24 2019 Dec   24    NA       NA     NA
# 6588 2020-01-14 2020 Jan   14    NA       NA     NA
# 6797 2020-08-10 2020 Aug   10    NA       NA     NA
# 6875 2020-10-27 2020 Oct   27    NA       NA     NA
# 6876 2020-10-28 2020 Oct   28    NA       NA     NA

# %%
ndays <- length(working_temps$Year) # number of days, 1588
working_temps$mean.temp <- round(approx(1:ndays, working_temps$mean.temp, n=ndays)$y, 1) # linearly interpolate missing dates

# %% [markdown]
# Now we can take a look at the time series and how temperatures are distributed.  The first thing to notice from the time series is that there appears to be seasonality in the data.  Of course this makes sense given that we are looking at temperature data, however, there is some subtlety in what we are observing.  In the context time series analysis, seasonality refers to an autoregressive influence that occurs periodically.  For example, had we done this analysis on monthly data it would make sense that the temperature in Jan 2020 would be a good indicator of the temperature in Jan 2021, hence we would expect a season model whose autoregressive influence occurs every 12 months.  However, it does not seem reasonable to expect that the temperature on Jan 01, 2020 will be a good indicator of the temperature on Jan 01, 2021.  So, although general weather patterns exhibit seasonality, we do not fit a seasonal time series model.

# %%
ggplot(data=working_temps, aes(x=Date.Time, y=mean.temp)) + geom_line() +
        ggtitle('Toronto Temperature') + xlab('Year') + ylab('Temperature (Celcius)') +
        theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
ggplot(data=working_temps, aes(x=mean.temp)) + geom_histogram(binwidth=1, alpha=0.5, color='black') +
        ggtitle('Distribution of Temperatures') + xlab('Mean Temperature') + ylab('Count') +
        theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %% [markdown]
# The periodic nature of the data still presents a problem.  For instance, we see below that every year, between June and August, temperature will be a lot higher than in the other months.  Again, this is expected, since summer is the warmest time of the year, however it still presents a problem because we require stationary data in order to perform meaningful analysis.  Below we will confirm our suspicion that the data is not stationary and look at a way to remedy this issue.

# %%
ggplot(working_temps) + geom_boxplot(aes(y=mean.temp, 
                                         x=factor(Month, levels=month.abb), 
                                         fill=as.character(Year))) + scale_fill_grey(start = 0.8, end = 0.2) +
                        ylab('Temperature') + xlab('Month') + ggtitle('Mean Temperature by Month') +
                        theme(plot.title = element_text(hjust = 0.5)) + labs(fill='Year')
# Out:
# plot without title

# %% [markdown]
# # 3. Assessing Stationarity
# To assess stationarity, the first thing we want to look at is autocorrelation.  The ACF plot (top) decays very slowly and Partial ACF (bottom) has significant lags beyond what we would expect in stationary data.  Both plots exhibit strong indicators that the data is in fact, not stationary.  Likewise, we can employ the Augmented Dickey-Fuller (ADF) test to test if the data is stationary.  There is plenty of reason to think the data is not stationary, so we expect the ADF test to return an insignifcant result (since it tests the null hypothesis that the data is not stationary).  If this is the case, there is nothing concrete we can gather from the test (since it is insignificant) but given the nature of the data we will proceed in assuming nonstationarity and attempt to remedy this problem.

# %%
acf <- ggAcf(working_temps$mean.temp, lag.max=120) + ggtitle('')
pacf <- ggPacf(working_temps$mean.temp, lag.max=120) + ggtitle('')
grid.arrange(acf, pacf, nrow=2)
# Out:
# plot without title

# %%
adf.test(working_temps$mean.temp)
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  working_temps$mean.temp
# Dickey-Fuller = -2.6214, Lag order = 11, p-value = 0.3152
# alternative hypothesis: stationary

# %% [markdown]
# As we expected, the test is not significant.  So, up to this point we have no reason to believe the data might be stationary.  In order to apply the Box-Jenkins framework we need stationary data, which we attempt to extract in the section below.

# %% [markdown]
# # 3. Model Fitting
# Here we fit an appropriate model given what we know about the data.  We know that data is not stationary, so our goal is to identify a deterministic trend and remove it, then model the remaining noise using the Box-Jenkins framework.  The periodic nature of the time series is reminiscant of a cosine curve that repeats yearly and, in fact, we can fit a cosine curve using least squares.  Consider the following cosine model,
# $$\mu_t = \beta \cos\left(\frac{2\pi t}{365} + \Phi\right)$$
# Where 365 represents the period (yearly), $\beta$ the amplitude of the curve and $\Phi$ manages the origin of the curve. Fitting this curve is not straight forward becase the parameters we need to estimate (in particular, $\Phi$) do not enter the equation linearly.  However, we can take advantage of the following trigonometric identity
# $$\cos(a+b) = \cos(a)\cos(b) - \sin(a)\sin(b)$$
# That is, we consider $a=2\pi t/365$ and $b=\Phi$ so that
# $$\begin{align}
# \beta \cos\left(\frac{2\pi t}{365} + \Phi\right) &= \beta \left(\cos\left(\frac{2\pi t}{365}\right)\cos\Phi - \sin\left(\frac{2\pi t}{365}\right)\sin\Phi\right)
# \end{align}$$
# and take $\beta_1=\beta\cos\Phi$ and $\beta_2=-\beta\sin\Phi$.  Hence
# $$\mu_t = \beta_1\cos\left(\frac{2\pi t}{365}\right) + \beta_2\sin\left(\frac{2\pi t}{365}\right)$$
# Now notice that
# $$\beta_1^2+\beta_2^2 = \beta^2(\cos^2\Phi+\sin^2\Phi) = \beta^2\iff \beta = \sqrt{\beta_1^2+\beta_2^2}$$
# $$\frac{\beta_1}{\beta_2} = -\frac{\sin\Phi}{\cos\Phi} = -\tan(\Phi)\iff \Phi = \tan^{-1}\left(\frac{\beta_1}{\beta_2}\right)$$
# which means we can determine $\mu_t$ by estimating $\beta_1, \beta_2$ using a linear regression

# %%
temps_ts <- ts(working_temps$mean.temp, start=c(2017, 1), f=365.25) 
X <- harmonic(temps_ts, 1)    # matrix of predictor variables
x1 <- data.frame(X)$cos.2.pi.t      # predictor 1
x2 <- data.frame(X)$sin.2.pi.t      # predictor 2
cos_model <- lm(temps_ts ~ x1 + x2)
summary(cos_model)
working_temps$cos_model <- as.double(fitted(cos_model))
head(working_temps)
# Out:
# Call:
# lm(formula = temps_ts ~ x1 + x2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.3079  -2.6651  -0.1072   2.8479  13.5560
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   9.8556     0.1046   94.23   <2e-16 ***
# x1          -12.0842     0.1487  -81.25   <2e-16 ***
# x2           -4.9477     0.1466  -33.75   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 4.151 on 1585 degrees of freedom
# Multiple R-squared:  0.8322,	Adjusted R-squared:  0.832
# F-statistic:  3930 on 2 and 1585 DF,  p-value: < 2.2e-16
#      Date.Time  Year Month Day max.temp min.temp mean.temp cos_model
# 5480 2017-01-01 2017 Jan   1    3.1      -0.5     1.3      -2.228624
# 5481 2017-01-02 2017 Jan   2    5.5       0.7     3.1      -2.311944
# 5482 2017-01-03 2017 Jan   3    4.8       2.4     3.6      -2.391663
# 5483 2017-01-04 2017 Jan   4    3.8      -7.6    -1.9      -2.467759
# 5484 2017-01-05 2017 Jan   5   -5.3     -10.3    -7.8      -2.540208
# 5485 2017-01-06 2017 Jan   6   -5.9     -11.8    -8.9      -2.608988

# %%
ggplot() + geom_point(data=working_temps, aes(x=Date.Time, y=mean.temp), alpha=0.6) + 
        geom_line(data=working_temps, aes(x=Date.Time, y=cos_model), size=1, color=1) +
        ggtitle('Mean Temperatures with Trend') + theme(plot.title = element_text(hjust = 0.5)) +
        xlab('Year') + ylab('Temperature')
# Out:
# plot without title

# %%
working_temps$diff_model <- working_temps[, 7] - working_temps[, 8]
ggplot(data=working_temps, aes(x=Date.Time, y=diff_model)) + geom_line() +
ggtitle('Differenced Model') + theme(plot.title = element_text(hjust = 0.5)) +
xlab('Year') + ylab('Temperature')
# Out:
# plot without title

# %%
adf.test(working_temps$diff_model)
# Out:
# Warning message in adf.test(working_temps$diff_model):
# "p-value smaller than printed p-value"
# 	Augmented Dickey-Fuller Test
#
# data:  working_temps$diff_model
# Dickey-Fuller = -8.8819, Lag order = 11, p-value = 0.01
# alternative hypothesis: stationary

# %% [markdown]
# So, we have fitted a cosine curve that represents the deterministic portion of the time series.  Now if we take the difference between the time series and its deterministic trend, we are left with the stochastic part which we can model using Box-Jenkins.  In addition, we feel confident about proceeding this way as the ADF test for the differenced time series is significant, hence we reject the null hypothesis in favor of the alternative, the data is stationary.

# %%
acf <- ggAcf(working_temps$diff_model, lag.max=120) + ggtitle('ACF & Partial ACF plot for Differenced Model')
pacf <- ggPacf(working_temps$diff_model, lag.max=120) + ggtitle('')
grid.arrange(acf, pacf, nrow=2)
# Out:
# plot without title

# %% [markdown]
# We see that the ACF plot of the differenced model decays much quicker than the original model and the PACF has only 3 significant lags, both indicators of a stationary ARMA process.  In order to fit the orders of the ARMA process we will use the extended ACF function to determine feasible models and compare diagnostics.

# %%
eacf(working_temps$diff_model, ar.max=5, ma.max=5)
# o is feasible
# x is not feasible
# Out:
# AR/MA
#   0 1 2 3 4 5
# 0 x x x x x x
# 1 x x x o o o
# 2 x x o o o o
# 3 x x x o o o
# 4 x x x o o o
# 5 x o x x o o

# %%
# evaluate a collection of possible models
diff_model.aic <- matrix(0, 5, 5)
diff_model.bic <- matrix(0, 5, 5)
for (i in 0:4) for (j in 0:4){
    noise.fit <- arima(working_temps$diff_model, order=c(i, 0, j), method="ML", include.mean = TRUE, optim.control = list(maxit=1000))
    diff_model.aic[i+1, j+1] <- noise.fit$aic
    diff_model.bic[i+1, j+1] <- BIC(noise.fit)
}

# %%
sort(unmatrix(diff_model.aic, byrow=FALSE))[1:10]
sort(unmatrix(diff_model.bic, byrow=FALSE))[1:10]
# Out:
#    r3:c3    r2:c4    r4:c3    r3:c4    r5:c5    r2:c5    r4:c4    r5:c3
# 7808.201 7809.517 7810.198 7810.200 7810.889 7810.912 7812.031 7812.061
#    r5:c4    r4:c5
# 7813.062 7813.442
#    r3:c3    r2:c3    r4:c1    r2:c4    r2:c2    r3:c2    r4:c2    r5:c1
# 7842.422 7842.686 7842.823 7843.738 7847.373 7848.011 7848.519 7849.377
#    r4:c3    r3:c4
# 7849.790 7849.791

# %%
model <- arima(working_temps$diff_model, order=c(3, 0, 3), method="ML", include.mean = TRUE)
model.res <- residuals(model)
qqnorm(model.res)
qqline(model.res)
tsdiag(model)
# Out:
# Plot with title "Normal Q-Q Plot"
# Plot with title "p values for Ljung-Box statistic"

# %%
tail(working_temps)
# Out:
#      Date.Time  Year Month Day max.temp min.temp mean.temp cos_model diff_model
# 7062 2021-05-02 2021 May   2   17.0     9.0      13.0      11.44579   1.554208
# 7063 2021-05-03 2021 May   3   13.3     7.7      10.5      11.66850  -1.168501
# 7064 2021-05-04 2021 May   4   11.7     7.2       9.4      11.89067  -2.490673
# 7065 2021-05-05 2021 May   5   13.1     6.1       9.6      12.11224  -2.512243
# 7066 2021-05-06 2021 May   6   12.8     4.6       8.7      12.33315  -3.633145
# 7067 2021-05-07 2021 May   7   10.1     5.1       7.6      12.55331  -4.953315

# %%
forecast.dates <- seq(as.Date('2021-05-08'), as.Date('2021-05-08') + 60, by='day')
forecast.start.day <- as.numeric(strftime(forecast.dates[1], format = "%j")) 
s <- '{forecast.dates[1]} is the {forecast.start.day}th day of the year'
print(glue(s))
# Out:
# 2021-05-08 is the 128th day of the year
